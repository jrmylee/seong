# %%
from textblob import TextBlob
import MIDI

# %%
sentence = "Technology is best when it brings people together"

# %%
ngram_object = TextBlob(sentence)

# %%
ngrams = ngram_object.ngrams(n=2)
print(ngrams)
# Out:
# [WordList(['Technology', 'is']), WordList(['is', 'best']), WordList(['best', 'when']), WordList(['when', 'it']), WordList(['it', 'brings']), WordList(['brings', 'people']), WordList(['people', 'together'])]

# %%
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict

# %%
import nltk

# %%
nltk.download('reuters')
# Out:
# [nltk_data] Downloading package reuters to /Users/jrmylee/nltk_data...
# True

# %%
model = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for sentence in reuters.sents():
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        model[(w1, w2)][w3] += 1
 
# Let's transform the counts to probabilities
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

# %%
reuters_tri = trigrams(sentence, pad_right=True, pad_left=True)

# %%
next(reuters_tri)
# Out:
# (None, None, 'AUTOMOTIVE')

# %%
next(reuters_tri)
# Out:
# (None, 'AUTOMOTIVE', 'TECHNOLOGIES')

# %%
defaultdict(lambda: defaultdict(lambda: 0))
# Out:
# defaultdict(<function __main__.<lambda>()>, {})

# %%
import mido

# %%
song = "/Users/jrmylee/Documents/dev/projects/mir/datasets/jazz_midi/doug-mckenzie-jazz/archive/A Sleepin' Bee.mid"
mid = mido.MidiFile(song)

# %%
import os
import sys
print(sys.path)
# Out:
# ['/Users/jrmylee/Documents/dev/projects/mir/projects/seongjin', '/Users/jrmylee/anaconda3/lib/python37.zip', '/Users/jrmylee/anaconda3/lib/python3.7', '/Users/jrmylee/anaconda3/lib/python3.7/lib-dynload', '', '/Users/jrmylee/.local/lib/python3.7/site-packages', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/aeosa', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/tempocnn-0.0.4-py3.7.egg', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/jams-0.3.4-py3.7.egg', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/tensorflow-1.15.2-py3.7-macosx-10.9-x86_64.egg', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/numpy-1.16.0-py3.7-macosx-10.9-x86_64.egg', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/mir_eval-0.6-py3.7.egg', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/termcolor-1.1.0-py3.7.egg', '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/tensorflow_estimator-1.15.1-py3.7.egg', '/Us
# ...

# %%
import MIDI

# %%
MIDI
# Out:
# <module 'MIDI' from '/Users/jrmylee/anaconda3/lib/python3.7/site-packages/MIDI/__init__.py'>

# %%
import music21
converter = music21.converter

# %%
score = converter.parse(song)

# %%
components = []

# %%
score.hasMeasures()
# Out:
# True

# %%
score.makeMeasures(inPlace=True)

# %%
for measure in score.recurse():
    print(measure)
# Out:
# <music21.stream.Measure 1 offset=0.0>
# MIDI 1:
# <music21.clef.TrebleClef>
# <music21.tempo.MetronomeMark Quarter=95.0>
# A- major
# <music21.meter.TimeSignature 4/4>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.chord.Chord E-3 C4 G#3>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.chord.Chord F#3 E-4 B3>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.chord.Chord F4 C#4 G#3>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.chord.Chord E4 B3 F#3>
# <music21.chord.Chord G#4 F#3>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Note F#>
# <music21.note.Note F>
# <music21.stream.Measure 2 offset=4.0>
# <music21.note.Note G>
# <music21.note.Note B->
# <music21.chord.Chord E-4 G#4 C5>
# ...

# %%
for notes in score.measure(0,1).recurse():
    print(notes)

# %%
for note in score.recurse().notes:
    print(note)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-c7ea28ec46e8> in <module>
#       1 for note in score.recurse().notes:
# ----> 2     print(note.type)
#
# AttributeError: 'Note' object has no attribute 'type'

# %%
for note in score.measure(1).notes:
    print(note)

# %%
dir(MIDI)
# Out:
# ['Events',
#  'MIDIFile',
#  'Track',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'base',
#  'chunks',
#  'partitioner',
#  'util']
